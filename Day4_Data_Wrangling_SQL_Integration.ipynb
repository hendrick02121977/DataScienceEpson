# %% [markdown]
# # Day 4: Data Wrangling & SQL Integration
#
# ## Data Wrangling
# - Handling Missing Values
# - Detecting Outliers
# - Data Normalization
#
# ## SQL Integration
# - Database Connections
# - Query Writing
# - Data Extraction
#
# ## Case Study
# Epson Production System Integration
